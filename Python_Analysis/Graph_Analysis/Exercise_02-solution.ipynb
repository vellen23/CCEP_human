# %% [markdown]
# # Exercise 02 - Paths, centralities, and community structure
#
# In this week's assignment we explore some of the key network analytic concepts introduced in lecture 02 in practice. We will calculate path-based network characteristics for empirical data sets and we develop a simple approach to detect community structures based on the heuristic optimisation of modularity. We finally calculate and visualise the degree distribution of real networks. We will use the following five empirical data sets:
#
# 1) the collaboration network of the OpenSource software community `kde`
# 2) the collaboration network of the OpenSource software community `gentoo`
# 3) the power grid of the western states of the USA
# 4) the contact network of students in a highschool
# 5) an information sharing network of physicians in the United States
#
# All of these data are available in a single SQLite database file, which you can find in Moodle.
#
# ## Task 1: Paths, diameter, and components
#
# ### 1.1 Connected components
#
# Implement Tarjan's algorithm for the calculation of connected components for an instance of `pathpy.Network` (see e.g. [Hopcroft and Tarjan 1973](https://dl.acm.org/citation.cfm?doid=362248.362272). Test your algorithm in the small toy example from lecture 2 (slide 14). Define a function that returns the relative size of the largest connected component (lcc) for a given network.
#
# Compare your results with the implementation given in pathpy, using the function `reduce_to_gcc` in `pathpy.algorithms.components`.

# %%
import numpy as np
import pathpy as pp

import sys
sys.setrecursionlimit(1500)

def lcc_size(n, verbose = False):
    # Tarjan's algorithm traverses a network with a depth-first-search.
    # Whenever we discover a new node, we assign a "dfs number" that is incremented. 
    # We recursively call the tarjan_visit function on that node. Each node is further assigned a 
    # "low link" number, which stores the minimum dfs number that can be reached from that node 
    # using at most one back edge, see https://en.wikipedia.org/wiki/Depth-first_search#Output_of_a_depth-first_search
    # We update this number whenever we find a link to an already discovered node.

    # The algorithm considers each node and link exactly once, so for a network with n nodes and m 
    # links its complexity is O(n+m).
    
    # this number is incremented whenever a new node is discovered
    i = 1

    # we store the current value of i as "dfs number" once a node is first discovered
    dfs_num = {}

    # low link as explained above
    low_link = {}

    # when the call to tarjan_visit finishes, the stack contains all nodes in the current connected component
    # conveniently, python arrays can be used as stacks by calling the append() and pop() functions
    stack = []
    
    components = {}
    component_sizes = {}

    def tarjan_visit(network, v):
        """Recursive method of Tarjan's algorithm that generates all nodes 
        that are in the same (strongly) connected component as node v."""
        nonlocal dfs_num
        nonlocal low_link
        nonlocal stack
        nonlocal i
        nonlocal components
        nonlocal component_sizes

        # start with node v
        dfs_num[v] = i
        low_link[v] = i
        stack.append(v)
        i += 1

        # for all successors w of v, recursively call function
        # if w has not been previously discovered
        for w in network.successors[v]:

            # if w has not been previously discovered
            # recursively apply tarjan_visit to w
            if w not in dfs_num:
                tarjan_visit(network, w)
                
                # update low_link[v] since we can reach w from v
                low_link[v] = min(low_link[v], low_link[w])

            # we discovered a link to an already discovered node w
            elif w in stack:
                
                # update low_link[v] since we can reach w from v
                low_link[v] = min(low_link[v], dfs_num[w])
        
        # a "root" node completed a DFS traversal
        if low_link[v] == dfs_num[v]:
            # stack contains nodes that are in same 
            # strongly connected component as v
            components[v] = set()
            while True:
                x = stack.pop()
                components[v].add(x)
                if x == v:
                    break
            component_sizes[v] = len(components[v])
    
    for v in n.nodes:
        # visit node if it has not been visited yet
        if v not in dfs_num:
            tarjan_visit(n, v)
    
    if verbose:        
        print(components)
        for v in n.nodes:
            print('{0} -> ({1}, {2})'.format(v, dfs_num[v], low_link[v]))
    
    return max(component_sizes.values())/n.ncount()

# %%
stop

# %%
# Example from L02 slide 22 with two connected components
n = pp.Network()
n.add_edge('a', 'b')
n.add_edge('b', 'c')
n.add_edge('a', 'c')
n.add_edge('d', 'f')
n.add_edge('d', 'g')
n.add_edge('d', 'e')
n.add_edge('e', 'f')
n.add_edge('f', 'g')

print(lcc_size(n))
n
# Out:
# 0.5714285714285714
# <style>
#     text.label_mUJjNbMQ {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_mUJjNbMQ line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_mUJjNbMQ circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="mUJjNbMQ">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='mUJjNbMQ_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"mUJjNbMQ"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "d", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "e", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "e", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "f", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}], "nodes": [{"id": "a", "text": "a", "color": "#99ccff", "size": 5.0}, {"id": "b", "text": "b", "color": "#99ccff", "size": 5.0}, {"id": "c", "text": "c", "color": "#99ccff", "size": 5.0}, {"id": "d", "text": "d", "color": "#99ccff", "size": 5.0}, {"id": "f", "text": "f", "color": "#99ccff", "size": 5.0}, {"id": "g", "text": "g", "color": "#99ccff", "size": 5.0}, {"id": "e", "text": "e", "color": "#99ccff", "size": 5.0}]};
#     var directed = false;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_mUJjNbMQ")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_mUJjNbMQ")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_mUJjNbMQ")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#mUJjNbMQ_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('mUJjNbMQ');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('mUJjNbMQ');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %%
n
# Out:
# <style>
#     text.label_DRlFzdTC {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_DRlFzdTC line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_DRlFzdTC circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="DRlFzdTC">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='DRlFzdTC_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"DRlFzdTC"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "d", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "e", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "e", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "f", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}], "nodes": [{"id": "a", "text": "a", "color": "#99ccff", "size": 5.0}, {"id": "b", "text": "b", "color": "#99ccff", "size": 5.0}, {"id": "c", "text": "c", "color": "#99ccff", "size": 5.0}, {"id": "d", "text": "d", "color": "#99ccff", "size": 5.0}, {"id": "f", "text": "f", "color": "#99ccff", "size": 5.0}, {"id": "g", "text": "g", "color": "#99ccff", "size": 5.0}, {"id": "e", "text": "e", "color": "#99ccff", "size": 5.0}]};
#     var directed = false;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_DRlFzdTC")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_DRlFzdTC")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_DRlFzdTC")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#DRlFzdTC_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('DRlFzdTC');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('DRlFzdTC');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %%
pp.algorithms.components.connected_components??

# %%
paths = pp.Paths()
paths.add_path('a,b,c,a')
paths.add_path('d,e,f,g,d,f')
pp.Network().from_paths(paths).to_undirected()
# Out:
# <style>
#     text.label_YAaCePAU {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_YAaCePAU line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_YAaCePAU circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="YAaCePAU">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='YAaCePAU_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"YAaCePAU"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "e", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "e", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "f", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}], "nodes": [{"id": "a", "text": "a", "color": "#99ccff", "size": 5.0}, {"id": "b", "text": "b", "color": "#99ccff", "size": 5.0}, {"id": "c", "text": "c", "color": "#99ccff", "size": 5.0}, {"id": "d", "text": "d", "color": "#99ccff", "size": 5.0}, {"id": "e", "text": "e", "color": "#99ccff", "size": 5.0}, {"id": "f", "text": "f", "color": "#99ccff", "size": 5.0}, {"id": "g", "text": "g", "color": "#99ccff", "size": 5.0}]};
#     var directed = false;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_YAaCePAU")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_YAaCePAU")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_YAaCePAU")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#YAaCePAU_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('YAaCePAU');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('YAaCePAU');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %%
# Directed network example
n = pp.Network(directed=True)
n.add_edge('a', 'b')
n.add_edge('b', 'a')
n.add_edge('a', 'c')
n.add_edge('b', 'c')
n.add_edge('c', 'd')
n.add_edge('d', 'c')
n
# Out:
# <style>
#     text.label_bfbvHCQg {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_bfbvHCQg line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_bfbvHCQg circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="bfbvHCQg">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='bfbvHCQg_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"bfbvHCQg"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "b", "target": "a", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "b", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "c", "target": "d", "color": "#999999", "width": 0.5, "weight": 0.5}, {"source": "d", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.5}], "nodes": [{"id": "a", "text": "a", "color": "#99ccff", "size": 5.0}, {"id": "b", "text": "b", "color": "#99ccff", "size": 5.0}, {"id": "c", "text": "c", "color": "#99ccff", "size": 5.0}, {"id": "d", "text": "d", "color": "#99ccff", "size": 5.0}]};
#     var directed = true;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_bfbvHCQg")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_bfbvHCQg")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_bfbvHCQg")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#bfbvHCQg_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('bfbvHCQg');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('bfbvHCQg');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %%
print(lcc_size(n, verbose=True))
# Out:
# {'c': {'d', 'c'}, 'a': {'b', 'a'}}
# a -> (1, 1)
# b -> (4, 1)
# c -> (2, 2)
# d -> (3, 2)
# 0.5

# %%
n = pp.Network(directed=True)
n.add_edge('a', 'b')
n.add_edge('a', 'c')
n.add_edge('b', 'd')
n.add_edge('b', 'e')
n.add_edge('d', 'b')
n.add_edge('d', 'e')
n.add_edge('e', 'd')
n
# Out:
# <style>
#     text.label_ojmmgZAq {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_ojmmgZAq line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_ojmmgZAq circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="ojmmgZAq">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='ojmmgZAq_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"ojmmgZAq"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.5}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 1.0}, {"source": "b", "target": "d", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "e", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "d", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "e", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "e", "target": "d", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}], "nodes": [{"id": "a", "text": "a", "color": "#99ccff", "size": 5.0}, {"id": "b", "text": "b", "color": "#99ccff", "size": 5.0}, {"id": "c", "text": "c", "color": "#99ccff", "size": 5.0}, {"id": "d", "text": "d", "color": "#99ccff", "size": 5.0}, {"id": "e", "text": "e", "color": "#99ccff", "size": 5.0}]};
#     var directed = true;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_ojmmgZAq")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_ojmmgZAq")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_ojmmgZAq")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#ojmmgZAq_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('ojmmgZAq');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('ojmmgZAq');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %%
print(lcc_size(n, verbose=True))
# Out:
# {'c': {'c'}, 'b': {'b', 'd', 'e'}, 'a': {'a'}}
# a -> (1, 1)
# b -> (3, 3)
# c -> (2, 2)
# d -> (4, 3)
# e -> (5, 4)
# 0.6

# %% [markdown]
# ### 1.2 Connected components in empirical data
#
# Read the five data sets from the SQLite database as *undirected* networks and compute the sizes of connected components. Would you say that these networks contain a *giant* connected component?

# %%
import sqlite3

con = sqlite3.connect('data/01_networks.db')
con.row_factory = sqlite3.Row

n_highschool = pp.Network.from_sqlite(con.execute('SELECT source, target FROM highschool'), directed=False)
n_kde = pp.Network.from_sqlite(con.execute('SELECT source, target FROM kde'), directed=False)
n_gentoo = pp.Network.from_sqlite(con.execute('SELECT source, target FROM gentoo'), directed=False)
n_powergrid = pp.Network.from_sqlite(con.execute('SELECT source, target FROM powergrid'), directed=False)
n_physicians = pp.Network.from_sqlite(con.execute('SELECT source, target FROM physicians'), directed=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-10-5408a88f17f2> in <module>
#       1 import sqlite3
#       2
# ----> 3 con = sqlite3.connect('data/01_networks.db')
#       4 con.row_factory = sqlite3.Row
#       5
#
# OperationalError: unable to open database file

# %%
pp.algorithms.components.reduce_to_gcc

# %%
n_highschool
# Out:
# <style>
#     text.label_ySHQzsYZ {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_ySHQzsYZ line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_ySHQzsYZ circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="ySHQzsYZ">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='ySHQzsYZ_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"ySHQzsYZ"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "n_28", "target": "n_3", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_106", "target": "n_3", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_147", "target": "n_3", "color": "#999999", "width": 0.5, "weight": 0.125}, {"source": "n_177", "target": "n_3", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_295", "target": "n_3", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_3", "target": "n_407", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_15", "target": "n_21", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_15", "target": "n_48", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_15", "target": "n_200", "color": "#999999", "width": 0.5, "weight": 0.05555555555555555}, {"source": "n_15", "target": "n_211", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_15", "target": "n_242", "color": "#999999", "width": 0.5, "weight": 0.0625}, {"source": "n_15", "target": "n_480", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_15", "target": "n_771", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_15", "target": "n_791", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_15", "target": "n_826", "color": "#999999", "width": 0.5, "weight": 0.0625}, {"source": "n_15", "target": "n_845", "color": "#999999", "width": 0.5, "weight": 0.05}, {"source": "n_20", "target": "n_634", "color": "#999999", "width": 0.5, "weight": 0.5}, {"source": "n_200", "target": "n_21", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_21", "target": "n_826", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_28", "target": "n_295", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_28", "target": "n_327", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_28", "target": "n_407", "color": "#999999", "width": 0.5, "weight": 0.05}, {"source": "n_28", "target": "n_441", "color": "#999999", "width": 0.5, "weight": 0.0625}, {"source": "n_28", "target": "n_478", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_45", "target": "n_48", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_45", "target": "n_79", "color": "#999999", "width": 0.5, "weight": 0.125}, {"source": "n_134", "target": "n_45", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_232", "target": "n_45", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_45", "target": "n_601", "color": "#999999", "width": 0.5, "weight": 0.08333333333333333}, {"source": "n_48", "target": "n_79", "color": "#999999", "width": 0.5, "weight": 0.125}, {"source": "n_48", "target": "n_488", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_62", "target": "n_650", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "n_65", "target": "n_681", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_65", "target": "n_809", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_601", "target": "n_79", "color": "#999999", "width": 0.5, "weight": 0.125}, {"source": "n_134", "target": "n_87", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_211", "target": "n_87", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_242", "target": "n_87", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_388", "target": "n_87", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_488", "target": "n_87", "color": "#999999", "width": 0.5, "weight": 0.07142857142857142}, {"source": "n_496", "target": "n_87", "color": "#999999", "width": 0.5, "weight": 0.1}, {"source": "n_826", "target": "n_87", ...

# %%
print(lcc_size(n_highschool))
# Out:
# 1.0

# %%
print(lcc_size(n_kde))
# Out:
# 1.0

# %%
print(lcc_size(n_kde))
# Out:
# 1.0

# %%
print(lcc_size(n_powergrid))
# Out:
# 1.0

# %%
print(lcc_size(n_physicians))
# Out:
# 0.4854771784232365

# %% [markdown]
# ### Task 1.3 Diameter and average path length in empirical data
#
# Use the functions `diameter` and `avg_path_length` in `shortest_paths` in `pathpy.algorithms.shortest_paths` to compute the diameter and the average shortest path length of the (largest connected component in the) `physicians`, `highschool`, and `gentoo` data. Interpret the differences while considering the different sizes of the network.

# %%
print("Diameter of highschool is ", pp.algorithms.shortest_paths.diameter(n_highschool))
print("Diameter of physicians is ", pp.algorithms.shortest_paths.diameter(n_physicians))
print("Diameter of gentoo is ", pp.algorithms.shortest_paths.diameter(n_gentoo))

print("Avg. path length of highschool is ", pp.algorithms.shortest_paths.avg_path_length(n_highschool))
print("Avg. path length of physicians is ", pp.algorithms.shortest_paths.avg_path_length(n_physicians))
print("Avg. path length of gentoo is ", pp.algorithms.shortest_paths.avg_path_length(n_gentoo))
# Out:
# Diameter of highschool is  12.0
# Diameter of physicians is  inf
# Diameter of gentoo is  8.0
# Avg. path length of highschool is  5.3180555555555555
# Avg. path length of physicians is  inf
# Avg. path length of gentoo is  3.101921691531873

# %%
n_physicians

# %% [markdown]
# ## Task 2: Modularity-based community detection
#
# ### 2.1 Partition Quality
#
# Implement the partition quality function $Q(n, C)$ for a given network `n` and a non-overlapping partitioning `C` of nodes into communities as introduced in lecture 2 on slide 22. Test your method in the toy example with the partitioning depicted on slide 26. Check whether you obtain the same value for the partition quality.

# %%
def Q(network, C):
    m = network.ecount()
    n = network.ncount()    
    A = network.adjacency_matrix(weighted=False)
    idx = network.node_to_name_map()
    nodes = [v for v in idx]
    q = 0.0
    for v in network.nodes:
        for w in network.nodes:
            if C[v] == C[w]:
                q += A[idx[v], idx[w]] - network.nodes[v]['degree']*network.nodes[w]['degree']/(2*m)
    q /= 2*m
    return q

# %%
n
# Out:
# <style>
#     text.label_AXyDBaSI {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_AXyDBaSI line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_AXyDBaSI circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="AXyDBaSI">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='AXyDBaSI_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"AXyDBaSI"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "b", "target": "a", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "b", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.3333333333333333}, {"source": "c", "target": "d", "color": "#999999", "width": 0.5, "weight": 0.5}, {"source": "d", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.5}], "nodes": [{"id": "a", "text": "a", "color": "#99ccff", "size": 5.0}, {"id": "b", "text": "b", "color": "#99ccff", "size": 5.0}, {"id": "c", "text": "c", "color": "#99ccff", "size": 5.0}, {"id": "d", "text": "d", "color": "#99ccff", "size": 5.0}]};
#     var directed = true;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_AXyDBaSI")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_AXyDBaSI")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_AXyDBaSI")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#AXyDBaSI_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('AXyDBaSI');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('AXyDBaSI');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %%
n
# Out:
# <style>
#     text.label_levFtAoh {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_levFtAoh line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_levFtAoh circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="levFtAoh">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='levFtAoh_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"levFtAoh"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "d", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "d", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "d", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "e", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "e", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "f", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}], "nodes": [{"id": "a", "text": "a", "color": "#99ccff", "size": 5.0}, {"id": "b", "text": "b", "color": "#99ccff", "size": 5.0}, {"id": "c", "text": "c", "color": "#99ccff", "size": 5.0}, {"id": "d", "text": "d", "color": "#99ccff", "size": 5.0}, {"id": "f", "text": "f", "color": "#99ccff", "size": 5.0}, {"id": "g", "text": "g", "color": "#99ccff", "size": 5.0}, {"id": "e", "text": "e", "color": "#99ccff", "size": 5.0}]};
#     var directed = false;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_levFtAoh")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_levFtAoh")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_levFtAoh")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#levFtAoh_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('levFtAoh');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('levFtAoh');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %%
n = pp.Network()
n.add_edge('a', 'b')
n.add_edge('b', 'c')
n.add_edge('a', 'c')
n.add_edge('b', 'd')
n.add_edge('d', 'f')
n.add_edge('d', 'g')
n.add_edge('d', 'e')
n.add_edge('e', 'f')
n.add_edge('f', 'g')

communities = {}
for x in ['a', 'b', 'g']:
    communities[x] = 1
for x in ['d', 'e', 'f', 'c']:
    communities[x] = 2

q = Q(n, communities)
print(q)
# Out:
# -0.08024691358024688

# %% [markdown]
# ### 2.2 Modularity Optimisation
#
# Implement a simple heuristic optimisation algorithm to calculate the optimal modularity $Q_{opt}$ across all partitions. The idea of this algorithm is as follows:
#
# 1) Start with a partitioning where you place each node in a separate community
# 2) Draw two communities uniformly at random and merge them to a single community iff this merge increases partition quality
# 3) Repeat the second step for a given number of iterations and output the final partitioning and partition quality
#
# Use your method to calculate $Q_{opt}$ for the toy example and plot the detected communities by coloring the nodes appropriately.

# %%
def Q_merge(network, C, merge=set()):
    m = network.ecount()
    n = network.ncount()    
    A = network.adjacency_matrix(weighted=False)
    idx = network.node_to_name_map()
    q = 0.0
    for v in network.nodes:
        for w in network.nodes:
            if C[v] == C[w] or (C[v] in merge and C[w] in merge):
                q += A[idx[v], idx[w]] - network.nodes[v]['degree']*network.nodes[w]['degree']/(2*m)
    q /= 2*m
    return q

def find_communities(network, iterations=100):
    
    # start with each node being in a separate cluster
    C = {}
    community_to_nodes = {}
    c = 0
    for n in network.nodes:
        C[n] = c
        community_to_nodes[c] = set([n])
        c += 1
    q = Q(network, C)
    communities = list(C.values())
    
    for i in range(iterations):
        # randomly choose two communities
        x, y = np.random.choice(communities, size=2)
        # check Q of merged communities
        q_new = Q_merge(network, C, merge=set([x, y]))
        if q_new > q:
            # actually merge the communities
            for n in community_to_nodes[x]:
                C[n] = y
            community_to_nodes[y] = community_to_nodes[y] | community_to_nodes[x]
            q = q_new
            communities.remove(x)
            del community_to_nodes[x]
    return C, q

# %% [markdown]
# To make this task a bit simpler, I provide you with the following method, which generates a community-based node-color mapping that you can use to color nodes according to (a maximum of 20) communities (hint: use the `node_color` parameter of the `pathpy.visualisation.plot` function).

# %%
def map_colors(n, communities):
    colors = ['red', 'green', 'blue', 'orange', 'yellow', 'cyan', 'blueviolet', \
              'chocolate', 'magenta', 'navy', 'plum', 'thistle', 'wheat', 'turquoise', \
              'steelblue', 'grey', 'powderblue', 'orchid', 'mintcream', 'maroon']
    node_colors = {}
    community_color_map = {}
    i = 0
    for v in n.nodes:
        if communities[v] not in community_color_map:
            community_color_map[communities[v]] = i%len(colors)
            i += 1
        node_colors[v] = colors[community_color_map[communities[v]]]
    return node_colors

# %%
n
# Out:
# <style>
#     text.label_dVDmGSgl {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_dVDmGSgl line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_dVDmGSgl circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="dVDmGSgl">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='dVDmGSgl_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"dVDmGSgl"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "d", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "d", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "d", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "e", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "e", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "f", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}], "nodes": [{"id": "a", "text": "a", "color": "#99ccff", "size": 5.0}, {"id": "b", "text": "b", "color": "#99ccff", "size": 5.0}, {"id": "c", "text": "c", "color": "#99ccff", "size": 5.0}, {"id": "d", "text": "d", "color": "#99ccff", "size": 5.0}, {"id": "f", "text": "f", "color": "#99ccff", "size": 5.0}, {"id": "g", "text": "g", "color": "#99ccff", "size": 5.0}, {"id": "e", "text": "e", "color": "#99ccff", "size": 5.0}]};
#     var directed = false;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_dVDmGSgl")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_dVDmGSgl")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_dVDmGSgl")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#dVDmGSgl_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('dVDmGSgl');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('dVDmGSgl');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %%
C, q_opt = find_communities(n, iterations=6)
print(C)
print(q_opt)
pp.visualisation.plot(n, node_color=map_colors(n, C))
# Out:
# {'a': 1, 'b': 1, 'c': 1, 'd': 3, 'f': 5, 'g': 5, 'e': 3}
# 0.2160493827160494
# <style>
#     text.label_vzLeLSPy {
#         text-anchor: middle;
#         font-size: 8px;
#         font-family: Arial, Helvetica, sans-serif;
#         fill: #999999;
#         stroke: #ffffff;
#         stroke-width: 0.1px;
#         opacity: 1.0;
#     }
#     .links_vzLeLSPy line {
#     stroke-opacity: 1.0;
#     }
#     .arrows svg:path {
#         stroke: #666;
#     }
#     .nodes_vzLeLSPy circle {
#     stroke: #fff;
#     stroke-width: 0.5px;
#     }
# </style>
#
# <svg width="400" height="400" id="vzLeLSPy">
#     <text x="20" y="20" font-family="sans-serif" font-size="14px" fill="#666" style="cursor: pointer"
#         id='vzLeLSPy_svg_txt'>[save svg]</text>
# </svg>
#
# <script charset="utf-8" src="https://d3js.org/d3.v4.min.js"></script>
# <script charset="utf-8">
#
# // Load via requireJS if available (jupyter notebook environment)
# try {
#     // Problem: require.config will raise an exception when called for the second time
#     require.config({
#         paths: {
#             //d3: "https://d3js.org/d3.v4.min"
#             d3: "https://d3js.org/d3.v4.min.js".replace(".js", "")
#         }
#     });
#     console.log("Detected requireJS");
# }
# catch(err){
#     // a reference error indicates that requireJS does not exist.
#     // other errors may occur due to multiple calls to config
#     if (err instanceof ReferenceError){
#         console.log("Detected no requireJS");
#
#         // Helper function that waits for d3js to be loaded
#         require = function require(symbols, callback) {
#             var ms = 5;
#             window.setTimeout(function(t) {
#                 if (window[symbols[0]])
#                     callback(window[symbols[0]]);
#                 else
#                     window.setTimeout(arguments.callee, ms);
#             }, ms);
#         }
#     }
# }
#
# // wait until d3js has been loaded
# require(["d3"], function(d3) {
#     var svg = d3.select("#"+"vzLeLSPy"), radius = 6, width = +svg.attr("width"), height = +svg.attr("height");
#
#     var color = d3.scaleOrdinal(d3.schemeCategory20);
#
#     var graph = {"links": [{"source": "a", "target": "b", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "a", "target": "c", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "b", "target": "d", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "d", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.16666666666666666}, {"source": "d", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "d", "target": "e", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "e", "target": "f", "color": "#999999", "width": 0.5, "weight": 0.25}, {"source": "f", "target": "g", "color": "#999999", "width": 0.5, "weight": 0.25}], "nodes": [{"id": "a", "text": "a", "color": "red", "size": 5.0}, {"id": "b", "text": "b", "color": "red", "size": 5.0}, {"id": "c", "text": "c", "color": "red", "size": 5.0}, {"id": "d", "text": "d", "color": "green", "size": 5.0}, {"id": "f", "text": "f", "color": "blue", "size": 5.0}, {"id": "g", "text": "g", "color": "blue", "size": 5.0}, {"id": "e", "text": "e", "color": "green", "size": 5.0}]};
#     var directed = false;
#
#     var simulation = d3.forceSimulation()
#        .force("link", d3.forceLink().id(function(d) { return d.id; }).strength(function(d){return d.weight;}))
#         .force("charge", d3.forceManyBody().strength(-20).distanceMax(400))
#        .force("repelForce", d3.forceManyBody().strength(-200).distanceMax(100))
#        .force("center", d3.forceCenter(400 / 2, 400 / 2))
#        .alphaTarget(0.0);
#
#     svg.append("defs").selectAll("marker")
#         .data(["end"])
#     .enter().append("marker")
#         .attr("id", String)
#         .attr("viewBox", "0 -5 20 20")
#         .attr("refX", 34)
#         .attr("refY", 0)
#         .attr("markerWidth", 15)
#         .attr("markerHeight", 15)
#         .attr("orient", "auto")
#     .append("path")
#         // draws a filled path (triangle) between three points
#         .attr("d", "M0,-5 L20,0 L0,5 z")
#         .attr("fill", '#999')
#         .attr("stroke", 'none');
#
#     var g = svg.append("g")
#         .attr("class", "everything");
#
#     var link = g.append("g")
#         .attr("class", "links_vzLeLSPy")
#         .selectAll("line")
#         .data(graph.links)
#         .enter().append("line")
#         .attr("stroke-width", function(d) { return d.width; })
#         .attr("stroke", function(d) { return d.color; } );
#
#     if (directed)
#         link.attr("marker-end", "url(#end)");
#
#     var node_g = g.append("g")
#         .attr("class", "nodes_vzLeLSPy")
#         .selectAll("circle")
#         .data(graph.nodes)
#         .enter()
#         .append("g");
#
#     var node = node_g.append("circle")
#         .attr('id', function(d) { return d.id; })
#         .attr("r", function(d) { return d.size; })
#         .attr("fill", function(d) { return d.color; })
#         .call(d3.drag()
#             .on("start", dragstarted)
#             .on("drag", dragged)
#             .on("end", dragended));
#
#     var text = node_g.append("text")
#     .attr("x", [0, -10][0])
#     .attr("y", [0, -10][1]+3)
#     .attr("id", function(d) {return d.id; })
#     .attr("class", "label_vzLeLSPy")
#     .text(function(d) { return d.id; });
#
#     node.append("title")
#         .text(function(d) { return d.text; });
#
#     var zoom_handler = d3.zoom()
#         .on("zoom", zoom_actions);
#     zoom_handler(svg);
#
#     // attach event handler for svg export
#     d3.select('#vzLeLSPy_svg_txt').on("click", save_svg);
#
#     simulation
#         .nodes(graph.nodes)
#         .on("tick", ticked);
#
#     simulation.force("link")
#         .links(graph.links);
#
#     function ticked() {
#         link.attr("x1", function(d) { return d.source.x; })
#             .attr("y1", function(d) { return d.source.y; })
#             .attr("x2", function(d) { return d.target.x; })
#             .attr("y2", function(d) { return d.target.y; });
#
#          text.attr("transform", transform);
#
#
#         text.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#
#         node.attr("cx", function(d) { return d.x; })
#             .attr("cy", function(d) { return d.y; });
#     }
#
#     function transform(d) {
#         return "translate(" + d.x + "," + d.y + ")";
#     }
#
#     function dragstarted(d) {
#     if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#     d.fx = d.x;
#     d.fy = d.y;
#     }
#
#     function zoom_actions(){
#         g.attr("transform", d3.event.transform)
#     }
#
#     function dragged(d) {
#     d.fx = d3.event.x;
#     d.fy = d3.event.y;
#     }
#
#     function dragended(d) {
#     if (!d3.event.active) simulation.alphaTarget(0);
#     d.fx = null;
#     d.fy = null;
#     }
#
#     function to_svg() {
#         // Returns a SVG representation of the current state of the visualisation
# 	    var svg  = document.getElementById('vzLeLSPy');
# 	    var xml = (new XMLSerializer).serializeToString(svg);
#         return xml;
#     }
#
#     function save_svg() {
#         var svg  = document.getElementById('vzLeLSPy');
#         var xml = (new XMLSerializer).serializeToString(svg);
#         var blob = new Blob([xml], {type: 'text/xml'});
#         if(window.navigator.msSaveOrOpenBlob) {
#             window.navigator.msSaveBlob(blob, 'network.svg');
#         }
#         else{
#             var elem = window.document.createElement('a');
#             elem.href = window.URL.createObjectURL(blob);
#             elem.download = 'network.svg';
#             document.body.appendChild(elem);
#             elem.click();
#             document.body.removeChild(elem);
#         }
#     }
# });
# </script>

# %% [markdown]
# ### 2.3 Synthetic Network Generation
#
# Create a simple *synthetic network* with a strong (and known) community structure as follows:
#
# 1) Generate two networks $c1$ and $c2$ with $50$ nodes each and add $200$ links at random to each of the networks. For this, you can use the `numpy.random.choice` function introduced in the second tutorial.
# 2) Use `pathpy`'s $+$-operator to combine the two networks to a single network with two connected components.
# 3) Add $5$ links that randomly interconnect nodes across the two components $c1$ and $c2$, thus generating a connected network.
#
# Visualise the network generated by this method.

# %%
c_1 = pp.Network()
c_2 = pp.Network()

for i in range(50):
    c_1.add_node(str(i))
    c_2.add_node(str(50+i))

for i in range(200):
    c_1.add_edge(np.random.choice(list(c_1.nodes)), np.random.choice(list(c_1.nodes)))
    c_2.add_edge(np.random.choice(list(c_2.nodes)), np.random.choice(list(c_2.nodes)))
    
n_clustered = c_1 + c_2

for i in range(5):
    n_clustered.add_edge(np.random.choice(list(c_1.nodes)), np.random.choice(list(c_2.nodes)))
   
n_clustered

# %% [markdown]
# ### 2.4 Heuristic optimisation vs. global optimum
#
# Define a community partitioning that corresponds to the "ground truth" communities in the network from 2.3 and calculate the partition quality $Q$ for this optimal partitioning. Use your method from Task 2.2 to find the partitioning with maximal modularity. Compare this value to the ground truth and visualise the corresponding community structures.

# %%
C_clustered = {}
for n in c_1.nodes:
    C_clustered[n] = 1
for n in c_2.nodes:
    C_clustered[n] = 2
    
q_opt = Q(n_clustered, C_clustered)
print('Optimal partition quality based on synthetic communities = {0}'.format(q_opt))

C, q_detected = find_communities(n_clustered, iterations=1500)
print('Optimal partition quality based on detected communities = {0}'.format(q_detected))

# %%
pp.visualisation.plot(n_clustered, node_color=map_colors(n_clustered, C))

# %% [markdown]
# ### 2.5 Community assortativity coefficient
#
# Using the definition from lecture 2, slide 29, implement a function that computes the theoretical maximum modularity $Q_{max}$ fora given network and partition. Test your function for the toy example and try to reproduce the *community assortativity coefficient* reported on slide 29. Calculate the community assortativity coefficient for the synthetic example from Task 3.4 and compare it to the modularity of this network.

# %%
def Qmax(network, C):
    m = network.ecount()
    qmax = 2*m
    for v in network.nodes:
        for w in network.nodes:
            if C[v] == C[w]:
                qmax -= network.nodes[v]['degree']*network.nodes[w]['degree']/(2*m)
    
    return qmax/(2*m)

# %%
n = pp.Network()
n.add_edge('a', 'b')
n.add_edge('b', 'c')
n.add_edge('a', 'c')
n.add_edge('b', 'd')
n.add_edge('d', 'f')
n.add_edge('d', 'g')
n.add_edge('d', 'e')
n.add_edge('e', 'f')
n.add_edge('f', 'g')

communities = {}
for x in ['a', 'b', 'c']:
    communities[x] = 1
for x in ['d', 'e', 'f', 'g']:
    communities[x] = 2

q_max = Qmax(n, communities)
print(q_max)

C, q_opt = find_communities(n)
print(q_opt)

print("Community assortativity coefficient for toy example = ", q_opt/q_max)

# %%
q_opt = Q(n_clustered, C_clustered)
q_max = Qmax(n_clustered, C_clustered)
print(q_max)
print(q_opt)
print("Community assortativity coefficient for synthetic network = ", q_opt/q_max)
