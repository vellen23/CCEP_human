# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import pandas as pd

import sys

sys.path.append('T:\EL_experiment\Codes\CCEP_human\Python_Analysis/py_functions')

from scipy.stats import norm
from tkinter import *
import scipy
from scipy import signal

import platform
from glob import glob
from scipy.spatial import distance
import basic_func as bf
from scipy.integrate import simps
from numpy import trapz
import tqdm
from matplotlib.patches import Rectangle
from pathlib import Path
import statsmodels.api as sm
import statsmodels.formula.api as smf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from scipy import stats

#
from scipy.signal import hilbert, butter, filtfilt
import scipy.stats as stats
from tqdm.notebook import trange, tqdm
import load_summary as ls
cwd             = os.getcwd()

##all 
cond_vals   = np.arange(4)
cond_labels = ['BM', 'BL', 'Fuma', 'Benzo']
cond_colors = ['#494159','#594157', "#F1BF98","#8FB996"]
dist_groups = np.array([[0,15],[15,30],[30,5000]])
dist_labels = ['local (<15 mm)', 'short (<30mm)', 'long']
sub_path  ='X:\\4 e-Lab\\' # y:\\eLab

sys.path.append('T:\\EL_experiment\Codes\CCEP_human\Python_Analysis\py_functions')
sys.path.append('X:\\4 e-Lab\e-Lab shared code\Softwares\Connectogram')
sys.path.append('T:\\EL_experiment\Codes\\UBELIX_EvM\\NMF\\functions')
path_connectogram = 'X:\\4 e-Lab\e-Lab shared code\Softwares\Connectogram'
from main_script import ConnectogramPlotter
cwp = os.getcwd()

# %%
CIRC_AREAS_FILEPATH = 'X:\\4 e-Lab\e-Lab shared code\Softwares\Connectogram\circ_areas.xlsx'
tab_region = pd.read_excel(CIRC_AREAS_FILEPATH, sheet_name='plot')
tab_region = tab_region.sort_values('Order').reset_index(drop=True)
regions_all = tab_region.Area.values
region_col = tab_region.color.values

CIRC_AREAS_FILEPATH = 'X:\\4 e-Lab\e-Lab shared code\Softwares\Connectogram\circ_areas.xlsx'
all_region = pd.read_excel(CIRC_AREAS_FILEPATH, sheet_name='atlas')

# %%
plt.rcParams.update({
            'font.family': 'arial',
            'font.size': 12,
            'xtick.labelsize': 8,
            'ytick.labelsize': 8,
            'legend.fontsize': 9,
            'svg.fonttype': 'none',
            'font.size': 10,
            'axes.titlesize': 10,
            'axes.labelsize': 8,
            'xtick.labelsize': 8,
            'ytick.labelsize': 8,
            'legend.fontsize': 9,
            'figure.titlesize': 10
        })

# %%
def adding_destrieux(data_con, pair=1, area='Destrieux'):
    # area == 'Region' or 'Area'
    CIRC_AREAS_FILEPATH = 'X:\\4 e-Lab\e-Lab shared code\Softwares\Connectogram\circ_areas.xlsx'
    atlas = pd.read_excel(CIRC_AREAS_FILEPATH, sheet_name='atlas')
    if pair:
        for subregion in np.unique(data_con[['StimA', 'ChanA']]):
            region = atlas.loc[atlas.Abbreviation == subregion, area].values
            if len(region) > 0:
                data_con.loc[data_con.StimA == subregion, 'StimR'] = region[0]
                data_con.loc[data_con.ChanA == subregion, 'ChanR'] = region[0]
            else:
                print(subregion)
                data_con.loc[data_con.StimA == subregion, 'StimR'] = 'U'
                data_con.loc[data_con.ChanA == subregion, 'ChanR'] = 'U'
    else:
        for subregion in np.unique(data_con[['ChanA']]):
            region = atlas.loc[atlas.Abbreviation == subregion, area].values
            if len(region) > 0:
                data_con.loc[data_con.ChanA == subregion, 'ChanR'] = region[0]
            else:
                data_con.loc[data_con.ChanA == subregion, 'ChanR'] = 'U'
    return data_con

# %%
#import BM_across_plots as plotting

cwd = os.getcwd()

##all
cond_vals = np.arange(4)
cond_labels = ['BM', 'BL', 'Fuma', 'Benzo']
cond_colors = ['#494159', '#594157', "#F1BF98", "#8FB996"]
dist_groups = np.array([[0, 15], [15, 30], [30, 5000]])
dist_labels = ['local (<15 mm)', 'short (<30mm)', 'long']
sub_path = 'X:\\4 e-Lab\\'  # y:\\eLab

##
subjs = ["EL010", "EL011", "EL012", "EL013", "EL014", "EL015", "EL016", "EL019", "EL020", "EL021",
         "EL022", "EL024", "EL026", "EL027", "EL028"]

# %%
CIRC_AREAS_FILEPATH = 'X:\\4 e-Lab\e-Lab shared code\Softwares\Connectogram\circ_areas.xlsx'
atlas = pd.read_excel(CIRC_AREAS_FILEPATH, sheet_name='atlas')

# %%
con_all = ls.get_connections(subjs, sub_path)
#con_all_ss = ls.get_connections_sleep(subjs, sub_path, ['Wake'])
con_all.loc[(con_all.True_peak == 0), 'Sig'] =0
con_all.loc[(con_all.Sig >0), 'Sig'] =1
con_all = con_all[(con_all.Sig>=0)].reset_index(drop=True)
data_mean = adding_destrieux(con_all[['Subj','Stim', 'Chan', 'Sig', 'd', 'StimA', 'ChanA','Hemi']], pair=1, area='Destrieux')
data_mean = data_mean.groupby(['Hemi','StimR', 'ChanR'], as_index=False)['Sig'].mean()
# Out:
# C:\Users\i0328442\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\i0328442\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Unknown

# %%
import gzip

# Function to read the parcel names into a list.
def read_parcel_names(file_path):
    with open(file_path, 'r') as f:
        parcels = f.read().splitlines()
    return parcels

# Function to read the gzipped matrix file into a DataFrame.
# Function to load the matrix data from a .txt.gz file
def load_matrix(matrix_file_path, headers):
    # Initialize a list to hold the matrix rows
    matrix_data = []
    
    # Open the gzipped text file
    with gzip.open(matrix_file_path, 'rt') as f:
        for line in f:
            # Skip lines that start with '#'
            if not line.startswith("#"):
                # Split the line by space and convert to floats
                row_data = [float(i) if i != 'nan' else np.nan for i in line.split()]
                matrix_data.append(row_data)
    
    # Create a DataFrame from the matrix_data list
    matrix_df = pd.DataFrame(matrix_data)
    # Set the parcel names as the row and column headers.
    matrix_df.columns = headers
    matrix_df.index = headers
    return matrix_df

# %%
# File paths - replace these with your actual file paths.
parcel_names_file_path = 'X:\\4 e-Lab\EvM\Projects\EL_experiment\Analysis\Supp_figures\F_tracts\Destrieux.txt'
matrix_file_path = 'X:\\4 e-Lab\EvM\Projects\EL_experiment\Analysis\Supp_figures\F_tracts\probability.txt.gz'

# Read the parcel names and matrix.
parcel_names = read_parcel_names(parcel_names_file_path)
matrix_ftract_P = load_matrix(matrix_file_path, parcel_names)
matrix_file_path = 'X:\\4 e-Lab\EvM\Projects\EL_experiment\Analysis\Supp_figures\F_tracts\onset_delay__median.txt.gz'
matrix_ftract_delay = load_matrix(matrix_file_path, parcel_names)

# %%
hemi_sel ='L'

# %%
# Clean the parcel names according to your specifications

cleaned_parcel_names = []
if hemi_sel =='L':
    for name in parcel_names:
        if name.startswith('ctx_lh_'):
            cleaned_name =name.replace('ctx_lh_', '')  # Keep only the part after the last underscore
        elif name.startswith('Left-'):
            cleaned_name = name.replace('Left-', '')  # Keep only the part after the last underscore
        elif name.startswith('ctx_rh_'):
            cleaned_name ='R' # name.replace('ctx_rh_', '')  # Keep only the part after the last underscore
        elif name.startswith('Right-'):
            cleaned_name = 'R' # name.replace('Right-', '')  # Keep only the part after the last underscore
        else:
            cleaned_name = name  # If it doesn't match the above, keep the original name
        cleaned_parcel_names.append(cleaned_name)
else:
    for name in parcel_names:
        if name.startswith('ctx_rh_'):
            cleaned_name =name.replace('ctx_rh_', '')  # Keep only the part after the last underscore
        elif name.startswith('Right-'):
            cleaned_name = name.replace('Right-', '')  # Keep only the part after the last underscore
        elif name.startswith('ctx_lh_'):
            cleaned_name ='l' # name.replace('ctx_rh_', '')  # Keep only the part after the last underscore
        elif name.startswith('Left-'):
            cleaned_name = 'l' # name.replace('Right-', '')  # Keep only the part after the last underscore
        else:
            cleaned_name = name  # If it doesn't match the above, keep the original name
        cleaned_parcel_names.append(cleaned_name)

# %%
matrix_ftract = load_matrix(matrix_file_path, cleaned_parcel_names)
matrix_long_df = matrix_ftract.reset_index().melt(id_vars=['index'], var_name='ChanR', value_name='P')
matrix_long_df.rename(columns={'index': 'StimR'}, inplace=True)
matrix_long_df = matrix_long_df.groupby(['StimR', 'ChanR'], as_index=False)['P'].mean()

# %%
df_merged = pd.merge(data_mean[data_mean.Hemi==hemi_sel], matrix_long_df, on=['StimR', 'ChanR'], how='left')

# %%
df_merged = df_merged[~np.isnan(df_merged.P)].reset_index(drop=True)

# %%
matrix_onset = df_merged.pivot_table(index='StimR', columns='ChanR', values='P')

# %%
g = sns.clustermap(matrix_onset, cmap='viridis',
                   row_cluster=False, col_cluster=False,
                   figsize=(8,8), vmin = 3, vmax = np.nanpercentile(matrix_onset.values,90))

# %%
# Use your merged dataframe
# df_merged = ...

# Perform linear regression
X = df_merged[['Sig']].values.reshape(-1, 1)  # Independent variable
y = df_merged['P'].values  # Dependent variable

# Create linear regression object
regression = LinearRegression()
regression.fit(X, y)

# Make predictions using the regression object
y_pred = regression.predict(X)

plt.figure(figsize=(4,4))
# Scatterplot of the data
plt.scatter(X, y, color='k',s = 2, label='Data', alpha =.7)

# Line of best fit
plt.plot(X, y_pred, color='red', linewidth=2, label='Fit')

# Calculate regression details
slope = regression.coef_[0]
intercept = regression.intercept_
r_value = r2_score(y, y_pred)
mse = mean_squared_error(y, y_pred)
std_err = np.sqrt(mse)

# Use scipy to calculate the p-value
slope, intercept, r_value, p_value, std_err = stats.linregress(df_merged['Sig'], df_merged['P'])

# Add regression details to plot
text_str = f'Intercept: {intercept:.3f}\nSlope: {slope:.3f}\nR-squared: {r_value**2:.3f}\nSE: {std_err:.3f}\nP-value: {p_value:.3e}'
plt.text(0.05, 0.95, text_str, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top')

# Additional plot settings
plt.xlabel('Connection Probability')
plt.ylabel('F-TRACt Connection Probability')
plt.title(hemi_sel+': Linear Regression of Connection Probability')
plt.savefig('X:\\4 e-Lab\EvM\Projects\EL_experiment\Analysis\Supp_figures\F_tracts\probability_fit.svg')
plt.show()

# %% [markdown]
# ## Unsupervised clustering

# %%
stop

# %%
matrix = matrix_onset.values

# %%
import community as community_louvain
import numpy as np
import networkx as nx
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform
import matplotlib.pyplot as plt

# Create a graph
G = nx.from_numpy_matrix(matrix, create_using=nx.Graph)

# Replace NaN values in the graph with a very high value or remove edges
for u, v, d in list(G.edges(data=True)):
    if np.isnan(d['weight']):
        G.remove_edge(u, v)  # Option to remove edge
    else:
        G[u][v]['weight'] = 1 / d['weight']  # Inverting weight for distance interpretation

# Detect communities
partition = community_louvain.best_partition(G, weight='weight')

# Visualizing the graph with communities
pos = nx.spring_layout(G)  # positions for all nodes
cmap = plt.get_cmap('viridis')
for com in set(partition.values()):
    list_nodes = [nodes for nodes in partition.keys() if partition[nodes] == com]
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size=20, node_color=cmap(com / max(partition.values())))
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-6f615d4fa42d> in <module>
#      17
#      18 # Detect communities
# ---> 19 partition = community_louvain.best_partition(G, weight='weight')
#      20
#      21 # Visualizing the graph with communities
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
import communityimport community.community_louvain as community_louvain
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-7cf02d3f9d4f> in <module>
#       2
#       3 # Community detection
# ----> 4 partition = community_louvain.best_partition(G)
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
# !pip install python-louvain --proxy http://i0328442:ArInZe!S23@proxy.insel.ch:8080
from community import community_louvain
communities =community_louvain.best_partition(G)
# Out:
# Collecting python-louvain
#   Using cached python-louvain-0.16.tar.gz (204 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: networkx in c:\users\i0328442\appdata\local\anaconda3\lib\site-packages (from python-louvain) (2.8.4)
# Requirement already satisfied: numpy in c:\users\i0328442\appdata\local\anaconda3\lib\site-packages (from python-louvain) (1.24.3)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9403 sha256=620ed46d72be58d1c4eadd30344da99ff8bf9f7ba64b4f25d519966e20bf7981
#   Stored in directory: c:\users\i0328442\appdata\local\pip\cache\wheels\11\c1\e7\f62a211c636275e2da798bf0c307a3ae79aeddaf2524a03ce4
# Successfully built python-louvain
# Installing collected packages: python-louvain
# Successfully installed python-louvain-0.16
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-140-b85c979f4446> in <module>
#       1 get_ipython().system('pip install python-louvain --proxy http://i0328442:ArInZe!S23@proxy.insel.ch:8080')
# ----> 2 from community import community_louvain
#       3 communities =community_louvain.best_partition(G)
#
# ImportError: cannot import name 'community_louvain' from 'community' (T:\EL_experiment\Codes\CCEP_human\Python_Analysis\venv\lib\site-packages\community\__init__.py)

# %%
import community as community_louvain


# Community detection
partition = community_louvain.best_partition(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-d08c641714e9> in <module>
#       3
#       4 # Community detection
# ----> 5 partition = community_louvain.best_partition(G)
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
nx.draw(G)

# %%
matrix_onset
# Out:
# ChanR                      Amygdala  AnteroHippocampus  \
# StimR
# Amygdala                     10.156             31.641
# AnteroHippocampus            23.000             17.969
# G_Ins_lg_and_S_cent_ins      26.758                NaN
# G_and_S_cingul-Ant           38.477                NaN
# G_front_inf-Opercular        32.500                NaN
# G_front_inf-Orbital             NaN                NaN
# G_front_inf-Triangul         45.000                NaN
# G_front_middle               56.543                NaN
# G_front_sup                  52.148                NaN
# G_insular_short              29.844                NaN
# G_oc-temp_med-Parahip        16.016                NaN
# G_occipital_middle              NaN                NaN
# G_orbital                    30.664                NaN
# G_pariet_inf-Angular            NaN                NaN
# G_pariet_inf-Supramar        41.000                NaN
# G_parietal_sup                  NaN                NaN
# G_rectus                     29.565                NaN
# G_temp_sup-G_T_transv           NaN                NaN
# G_temp_sup-Lateral           35.059                NaN
# G_temp_sup-Plan_polar        17.969                NaN
# G_temporal_inf               39.453                NaN
# G_temporal_middle            36.000             44.000
# Hippocampus                  12.109                NaN
# Lat_Fis-ant-Horizont         13.086                NaN
# Lat_Fis-ant-Vertical         29.000                NaN
# Lat_Fis-post                 57.500                NaN
# Pole_temporal                34.570             40.430
# PosteroHippocampus           24.805             20.532
# S_cingul-Marginalis             NaN                NaN
# S_circular_insula_ant           NaN                NaN
# S_circular_insula_inf        39.000                NaN
# S_circular_insula_sup        26.758                NaN
# S_collat_transv_ant          31.641             30.664
# S_front_inf                  14.062                NaN
# S_front_middle                  NaN                NaN
# S_front_sup                  70.703                NaN
# S_intrapariet_and_P_trans       NaN                NaN
# S_oc-temp_lat                59.000                NaN
# S_oc-temp_med_and_Lingual    41.000                NaN
# S_oc_middle_and_Lunatus         NaN                NaN
# S_occipital_ant                 NaN                NaN
# S_orbital-H_Shaped           54.102                NaN
# S_orbital_lateral               NaN                NaN
# S_orbital_med-olfact         74.365                NaN
# S_pericallosal               22.852                NaN
# S_postcentral                21.496                NaN
# S_precentral-inf-part           NaN                NaN
# S_suborbital                 25.000                NaN
# S_temporal_inf               56.000             52.637
# S_temporal_sup               45.500             56.000
#
# ChanR                      G_Ins_lg_and_S_cent_ins  G_and_S_cingul-Ant  \
# StimR
# Amygdala                                    35.000              75.586
# AnteroHippocampus                              NaN                 NaN
# G_Ins_lg_and_S_cent_ins                     16.992                 NaN
# G_and_S_cingul-Ant                             NaN                 NaN
# G_front_inf-Opercular                       30.000                 NaN
# G_front_inf-Orbital                            NaN              58.000
# G_front_inf-Triangul                        33.000                 NaN
# G_front_middle                              70.000                 NaN
# G_front_sup                                 44.924              36.000
# G_insular_short                             21.500                 NaN
# G_oc-temp_med-Parahip                       39.750              76.562
# G_occipital_middle                             NaN                 NaN
# G_orbital                                      NaN                 NaN
# G_pariet_inf-Angular                           NaN                 NaN
# G_pariet_inf-Supramar                       34.250                 NaN
# G_parietal_sup                                 NaN                 NaN
# G_rectus                                       NaN                 NaN
# G_temp_sup-G_T_transv                          NaN                 NaN
# G_temp_sup-Lateral                          18.000              68.000
# G_temp_sup-Plan_polar                       14.062              68.750
# G_temporal_inf                              53.125                 NaN
# G_temporal_middle                           16.016              58.000
# Hippocampus                                 24.805                 NaN
# Lat_Fis-ant-Horizont                        30.664                 NaN
# Lat_Fis-ant-Vertical                        30.000                 NaN
# Lat_Fis-post                                20.500                 NaN
# Pole_temporal                               32.070              63.689
# PosteroHippocampus                             NaN                 NaN
# S_cingul-Marginalis                            NaN                 NaN
# S_circular_insula_ant                          NaN                 NaN
# S_circular_insula_inf                       18.000              58.984
# S_circular_insula_sup                       20.500                 NaN
# S_collat_transv_ant                         40.000              63.867
# S_front_inf                                 67.773                 NaN
# S_front_middle                                 NaN              41.203
# S_front_sup                                 88.281                 NaN
# S_intrapariet_and_P_trans                   90.000                 NaN
# S_oc-temp_lat                               45.180                 NaN
# S_oc-temp_med_and_Lingual                   45.000              53.469
# S_oc_middle_and_Lunatus                        NaN                 NaN
# S_occipital_ant                                NaN                 NaN
# S_orbital-H_Shaped                          48.000              34.000
# S_orbital_lateral                              NaN                 NaN
# S_orbital_med-olfact                           NaN              35.000
# S_pericallosal                              80.469                 NaN
# S_postcentral                               50.000                 NaN
# S_precentral-inf-part                          NaN                 NaN
# S_suborbital                                36.000                 NaN
# S_temporal_inf                              57.500              70.000
# S_temporal_sup                              29.688              66.000
#
# ChanR                      G_front_inf-Opercular  G_front_inf-Orbital  \
# StimR
# Amygdala                                  71.680               54.834
# AnteroHippocampus                            NaN                  NaN
# G_Ins_lg_and_S_cent_ins                   31.000                  NaN
# G_and_S_cingul-Ant                           NaN               52.574
# G_front_inf-Opercular                     14.031                  NaN
# G_front_inf-Orbital                          NaN               22.119
# G_front_inf-Triangul                      23.414                  NaN
# G_front_middle                               NaN               34.773
# G_front_sup                                  NaN               70.000
# G_insular_short                           23.000                  NaN
# G_oc-temp_med-Parahip                     66.797               45.121
# G_occipital_middle                           NaN                  NaN
# G_orbital                                    NaN                  NaN
# G_pariet_inf-Angular                      36.500                  NaN
# G_pariet_inf-Supramar                     31.641                  NaN
# G_parietal_sup                               NaN                  NaN
# G_rectus                                     NaN                  NaN
# G_temp_sup-G_T_transv                     33.000                  NaN
# G_temp_sup-Lateral                        26.000               35.547
# G_temp_sup-Plan_polar                        NaN               39.227
# G_temporal_inf                               NaN                  NaN
# G_temporal_middle                            NaN               16.626
# Hippocampus                                  NaN                  NaN
# Lat_Fis-ant-Horizont                         NaN                  NaN
# Lat_Fis-ant-Vertical                      11.133                  NaN
# Lat_Fis-post                                 NaN                  NaN
# Pole_temporal                                NaN               58.980
# PosteroHippocampus                           NaN                  NaN
# S_cingul-Marginalis                       63.000                  NaN
# S_circular_insula_ant                     31.641                  NaN
# S_circular_insula_inf                     27.734               69.727
# S_circular_insula_sup                        NaN                  NaN
# S_collat_transv_ant                       55.000               18.945
# S_front_inf                               30.500                  NaN
# S_front_middle                               NaN               40.000
# S_front_sup                               52.148                  NaN
# S_intrapariet_and_P_trans                 57.031                  NaN
# S_oc-temp_lat                                NaN                  NaN
# S_oc-temp_med_and_Lingual                    NaN               58.307
# S_oc_middle_and_Lunatus                      NaN                  NaN
# S_occipital_ant                              NaN                  NaN
# S_orbital-H_Shaped                        45.000               27.734
# S_orbital_lateral                            NaN                  NaN
# S_orbital_med-olfact                         NaN               40.000
# S_pericallosal                               NaN                  NaN
# S_postcentral                                NaN                  NaN
# S_precentral-inf-part                        NaN                  NaN
# S_suborbital                                 NaN                  NaN
# S_temporal_inf                            66.000                  NaN
# S_temporal_sup                               NaN               56.177
#
# ChanR                      G_front_inf-Triangul  G_front_middle  G_front_sup  \
# StimR
# Amygdala                                 59.736          94.326       92.188
# AnteroHippocampus                           NaN             NaN          NaN
# G_Ins_lg_and_S_cent_ins                  51.500         104.453       62.891
# G_and_S_cingul-Ant                          NaN          41.406       36.000
# G_front_inf-Opercular                    28.000             NaN          NaN
# G_front_inf-Orbital                         NaN          42.500       58.754
# G_front_inf-Triangul                      8.602          29.688          NaN
# G_front_middle                           31.641          28.000       50.000
# G_front_sup                                 NaN          39.727       23.828
# G_insular_short                          17.969          58.008       35.773
# G_oc-temp_med-Parahip                    63.000          65.000       97.047
# G_occipital_middle                          NaN             NaN          NaN
# G_orbital                                   NaN          41.406          NaN
# G_pariet_inf-Angular                        NaN             NaN          NaN
# G_pariet_inf-Supramar                       NaN             NaN          NaN
# G_parietal_sup                              NaN             NaN          NaN
# G_rectus                                 18.945             NaN          NaN
# G_temp_sup-G_T_transv                       NaN             NaN          NaN
# G_temp_sup-Lateral                       32.500          58.000       66.000
# G_temp_sup-Plan_polar                       NaN          57.000       85.000
# G_temporal_inf                           54.102             NaN          NaN
# G_temporal_middle                        30.820          64.250       54.000
# Hippocampus                                 NaN             NaN          NaN
# Lat_Fis-ant-Horizont                     24.000          48.500          NaN
# Lat_Fis-ant-Vertical                      9.500             NaN          NaN
# Lat_Fis-post                             37.000             NaN          NaN
# Pole_temporal                               NaN          79.500       92.000
# PosteroHippocampus                          NaN             NaN          NaN
# S_cingul-Marginalis                         NaN             NaN          NaN
# S_circular_insula_ant                       NaN             NaN          NaN
# S_circular_insula_inf                    40.000          80.469       31.641
# S_circular_insula_sup                    22.426          41.406       41.895
# S_collat_transv_ant                      69.000          67.000       64.000
# S_front_inf                              30.000             NaN          NaN
# S_front_middle                           37.012          31.641       46.645
# S_front_sup                              54.000             NaN       33.594
# S_intrapariet_and_P_trans                39.000          41.406          NaN
# S_oc-temp_lat                            90.234          41.000          NaN
# S_oc-temp_med_and_Lingual                57.000          53.125       90.012
# S_oc_middle_and_Lunatus                     NaN             NaN          NaN
# S_occipital_ant                             NaN             NaN          NaN
# S_orbital-H_Shaped                       30.664          37.500       49.109
# S_orbital_lateral                           NaN          29.000          NaN
# S_orbital_med-olfact                     33.594          43.668       41.500
# S_pericallosal                           68.500             NaN          NaN
# S_postcentral                               NaN          39.500       19.922
# S_precentral-inf-part                    31.641          36.000          NaN
# S_suborbital                             50.574          45.168          NaN
# S_temporal_inf                           56.051          71.000       98.047
# S_temporal_sup                           49.219          56.000       56.500
#
# ChanR                      G_insular_short  ...  S_occipital_ant  \
# StimR                                       ...
# Amygdala                            46.000  ...           68.500
# AnteroHippocampus                      NaN  ...              NaN
# G_Ins_lg_and_S_cent_ins             27.734  ...              NaN
# G_and_S_cingul-Ant                     NaN  ...              NaN
# G_front_inf-Opercular               25.000  ...              NaN
# G_front_inf-Orbital                    NaN  ...              NaN
# G_front_inf-Triangul                28.711  ...              NaN
# G_front_middle                      68.750  ...              NaN
# G_front_sup                         59.961  ...              NaN
# G_insular_short                     16.016  ...              NaN
# G_oc-temp_med-Parahip               37.000  ...              NaN
# G_occipital_middle                     NaN  ...           29.250
# G_orbital                           30.832  ...              NaN
# G_pariet_inf-Angular                   NaN  ...              NaN
# G_pariet_inf-Supramar               47.266  ...              NaN
# G_parietal_sup                         NaN  ...              NaN
# G_rectus                            45.145  ...              NaN
# G_temp_sup-G_T_transv                  NaN  ...              NaN
# G_temp_sup-Lateral                  17.484  ...           93.000
# G_temp_sup-Plan_polar               19.922  ...              NaN
# G_temporal_inf                      55.000  ...              NaN
# G_temporal_middle                   24.000  ...           28.309
# Hippocampus                            NaN  ...              NaN
# Lat_Fis-ant-Horizont                31.250  ...              NaN
# Lat_Fis-ant-Vertical                27.367  ...              NaN
# Lat_Fis-post                        39.000  ...              NaN
# Pole_temporal                       45.312  ...              NaN
# PosteroHippocampus                     NaN  ...              NaN
# S_cingul-Marginalis                    NaN  ...              NaN
# S_circular_insula_ant                  NaN  ...              NaN
# S_circular_insula_inf               31.820  ...              NaN
# S_circular_insula_sup               24.194  ...              NaN
# S_collat_transv_ant                 53.125  ...              NaN
# S_front_inf                         39.453  ...              NaN
# S_front_middle                      44.668  ...              NaN
# S_front_sup                         59.473  ...              NaN
# S_intrapariet_and_P_trans           48.500  ...              NaN
# S_oc-temp_lat                       58.000  ...           27.500
# S_oc-temp_med_and_Lingual           59.500  ...              NaN
# S_oc_middle_and_Lunatus                NaN  ...           28.844
# S_occipital_ant                        NaN  ...            4.898
# S_orbital-H_Shaped                  38.000  ...              NaN
# S_orbital_lateral                   70.000  ...              NaN
# S_orbital_med-olfact                37.500  ...              NaN
# S_pericallosal                      82.000  ...              NaN
# S_postcentral                       76.562  ...              NaN
# S_precentral-inf-part               40.000  ...              NaN
# S_suborbital                        39.453  ...              NaN
# S_temporal_inf                      49.609  ...           12.109
# S_temporal_sup                      49.707  ...           39.727
#
# ChanR                      S_orbital-H_Shaped  S_orbital_lateral  \
# StimR
# Amygdala                               60.938             72.656
# AnteroHippocampus                         NaN                NaN
# G_Ins_lg_and_S_cent_ins                61.000                NaN
# G_and_S_cingul-Ant                     30.664                NaN
# G_front_inf-Opercular                  51.172                NaN
# G_front_inf-Orbital                    29.443                NaN
# G_front_inf-Triangul                   35.547                NaN
# G_front_middle                         47.877             34.000
# G_front_sup                            57.031                NaN
# G_insular_short                        29.688             33.594
# G_oc-temp_med-Parahip                  65.898                NaN
# G_occipital_middle                        NaN                NaN
# G_orbital                              17.000             30.332
# G_pariet_inf-Angular                      NaN                NaN
# G_pariet_inf-Supramar                  55.078                NaN
# G_parietal_sup                            NaN                NaN
# G_rectus                               16.016             36.035
# G_temp_sup-G_T_transv                     NaN                NaN
# G_temp_sup-Lateral                     47.133             29.000
# G_temp_sup-Plan_polar                  36.000                NaN
# G_temporal_inf                         39.000             45.312
# G_temporal_middle                      62.445             23.828
# Hippocampus                               NaN                NaN
# Lat_Fis-ant-Horizont                   31.641                NaN
# Lat_Fis-ant-Vertical                   30.664             22.000
# Lat_Fis-post                           54.500                NaN
# Pole_temporal                          56.039             55.398
# PosteroHippocampus                        NaN                NaN
# S_cingul-Marginalis                       NaN                NaN
# S_circular_insula_ant                     NaN                NaN
# S_circular_insula_inf                  61.914             78.516
# S_circular_insula_sup                  40.430             48.242
# S_collat_transv_ant                    42.000                NaN
# S_front_inf                            43.000             28.000
# S_front_middle                         48.000                NaN
# S_front_sup                            68.000             50.586
# S_intrapariet_and_P_trans              42.000                NaN
# S_oc-temp_lat                          58.740                NaN
# S_oc-temp_med_and_Lingual              47.266                NaN
# S_oc_middle_and_Lunatus                   NaN                NaN
# S_occipital_ant                           NaN                NaN
# S_orbital-H_Shaped                     16.016             17.969
# S_orbital_lateral                      27.000             13.500
# S_orbital_med-olfact                   28.711             37.500
# S_pericallosal                         40.918                NaN
# S_postcentral                          38.965                NaN
# S_precentral-inf-part                     NaN                NaN
# S_suborbital                           16.008                NaN
# S_temporal_inf                         54.051                NaN
# S_temporal_sup                         76.781             46.289
#
# ChanR                      S_orbital_med-olfact  S_pericallosal  \
# StimR
# Amygdala                                 72.656          67.172
# AnteroHippocampus                           NaN             NaN
# G_Ins_lg_and_S_cent_ins                  71.000          53.613
# G_and_S_cingul-Ant                       33.000             NaN
# G_front_inf-Opercular                       NaN             NaN
# G_front_inf-Orbital                      33.594             NaN
# G_front_inf-Triangul                     53.125          72.000
# G_front_middle                           66.000             NaN
# G_front_sup                              61.000             NaN
# G_insular_short                          33.350          46.000
# G_oc-temp_med-Parahip                    60.000             NaN
# G_occipital_middle                          NaN             NaN
# G_orbital                                30.000             NaN
# G_pariet_inf-Angular                        NaN             NaN
# G_pariet_inf-Supramar                    86.223             NaN
# G_parietal_sup                              NaN             NaN
# G_rectus                                    NaN             NaN
# G_temp_sup-G_T_transv                       NaN             NaN
# G_temp_sup-Lateral                       25.781             NaN
# G_temp_sup-Plan_polar                    86.328             NaN
# G_temporal_inf                           75.945             NaN
# G_temporal_middle                        60.000          73.000
# Hippocampus                                 NaN             NaN
# Lat_Fis-ant-Horizont                     81.750          55.500
# Lat_Fis-ant-Vertical                     51.000             NaN
# Lat_Fis-post                             87.000          32.500
# Pole_temporal                            53.125             NaN
# PosteroHippocampus                          NaN             NaN
# S_cingul-Marginalis                         NaN             NaN
# S_circular_insula_ant                       NaN             NaN
# S_circular_insula_inf                    76.562          86.500
# S_circular_insula_sup                    47.266          41.703
# S_collat_transv_ant                     106.836          57.500
# S_front_inf                              68.750             NaN
# S_front_middle                           48.000          57.000
# S_front_sup                              69.000          44.656
# S_intrapariet_and_P_trans                   NaN             NaN
# S_oc-temp_lat                            96.582             NaN
# S_oc-temp_med_and_Lingual                43.970          31.250
# S_oc_middle_and_Lunatus                     NaN             NaN
# S_occipital_ant                             NaN             NaN
# S_orbital-H_Shaped                       30.088          43.500
# S_orbital_lateral                        35.547             NaN
# S_orbital_med-olfact                     16.016             NaN
# S_pericallosal                              NaN             NaN
# S_postcentral                               NaN             NaN
# S_precentral-inf-part                       NaN             NaN
# S_suborbital                             22.852          44.500
# S_temporal_inf                           94.000          56.516
# S_temporal_sup                           98.500          58.500
#
# ChanR                      S_postcentral  S_precentral-inf-part  S_suborbital  \
# StimR
# Amygdala                          78.500                    NaN        72.656
# AnteroHippocampus                    NaN                    NaN           NaN
# G_Ins_lg_and_S_cent_ins           29.000                    NaN        60.938
# G_and_S_cingul-Ant                   NaN                    NaN           NaN
# G_front_inf-Opercular                NaN                    NaN           NaN
# G_front_inf-Orbital                  NaN                    NaN           NaN
# G_front_inf-Triangul                 NaN                 29.844        52.250
# G_front_middle                    58.984                 29.688        68.750
# G_front_sup                       40.430                    NaN           NaN
# G_insular_short                   45.656                 17.969        31.000
# G_oc-temp_med-Parahip             22.363                    NaN           NaN
# G_occipital_middle                   NaN                    NaN           NaN
# G_orbital                            NaN                    NaN           NaN
# G_pariet_inf-Angular                 NaN                    NaN           NaN
# G_pariet_inf-Supramar             14.062                    NaN           NaN
# G_parietal_sup                       NaN                    NaN           NaN
# G_rectus                             NaN                    NaN           NaN
# G_temp_sup-G_T_transv                NaN                    NaN           NaN
# G_temp_sup-Lateral                14.062                    NaN           NaN
# G_temp_sup-Plan_polar            101.500                    NaN           NaN
# G_temporal_inf                    41.000                    NaN           NaN
# G_temporal_middle                 35.500                 28.367        57.520
# Hippocampus                          NaN                    NaN           NaN
# Lat_Fis-ant-Horizont                 NaN                 40.000        55.078
# Lat_Fis-ant-Vertical              51.000                    NaN           NaN
# Lat_Fis-post                      19.500                    NaN        80.258
# Pole_temporal                     73.633                    NaN           NaN
# PosteroHippocampus                   NaN                    NaN           NaN
# S_cingul-Marginalis                  NaN                    NaN           NaN
# S_circular_insula_ant                NaN                    NaN           NaN
# S_circular_insula_inf             22.473                    NaN        46.621
# S_circular_insula_sup             35.547                 17.969        50.348
# S_collat_transv_ant               59.000                 53.125        47.000
# S_front_inf                       36.000                    NaN        84.199
# S_front_middle                       NaN                    NaN        61.426
# S_front_sup                       69.727                    NaN        62.000
# S_intrapariet_and_P_trans         31.641                    NaN           NaN
# S_oc-temp_lat                        NaN                    NaN           NaN
# S_oc-temp_med_and_Lingual         55.000                 58.984        42.871
# S_oc_middle_and_Lunatus              NaN                    NaN           NaN
# S_occipital_ant                      NaN                    NaN           NaN
# S_orbital-H_Shaped                   NaN                    NaN        21.000
# S_orbital_lateral                    NaN                    NaN           NaN
# S_orbital_med-olfact                 NaN                    NaN        28.111
# S_pericallosal                       NaN                    NaN        20.000
# S_postcentral                     14.750                    NaN           NaN
# S_precentral-inf-part                NaN                    NaN        98.523
# S_suborbital                         NaN                    NaN           NaN
# S_temporal_inf                    37.000                 27.344        65.576
# S_temporal_sup                    31.641                    NaN        67.852
#
# ChanR                      S_temporal_inf  S_temporal_sup
# StimR
# Amygdala                           51.172          41.406
# AnteroHippocampus                  24.652          26.000
# G_Ins_lg_and_S_cent_ins            25.781          16.016
# G_and_S_cingul-Ant                 42.383          41.203
# G_front_inf-Opercular              53.500             NaN
# G_front_inf-Orbital                   NaN          35.500
# G_front_inf-Triangul               56.055          45.000
# G_front_middle                     65.898          60.938
# G_front_sup                        81.445          51.586
# G_insular_short                    31.000          17.969
# G_oc-temp_med-Parahip              28.223          17.000
# G_occipital_middle                 54.000          17.000
# G_orbital                          33.594          38.250
# G_pariet_inf-Angular               82.422          33.000
# G_pariet_inf-Supramar              48.242          29.688
# G_parietal_sup                        NaN             NaN
# G_rectus                           39.453          18.000
# G_temp_sup-G_T_transv                 NaN             NaN
# G_temp_sup-Lateral                 29.688          27.734
# G_temp_sup-Plan_polar              34.000          24.000
# G_temporal_inf                     26.379          23.828
# G_temporal_middle                  22.676          23.000
# Hippocampus                        19.922           3.320
# Lat_Fis-ant-Horizont               87.000          15.031
# Lat_Fis-ant-Vertical               54.590          50.195
# Lat_Fis-post                       39.000          20.500
# Pole_temporal                      40.000          45.000
# PosteroHippocampus                 14.062          14.062
# S_cingul-Marginalis                   NaN             NaN
# S_circular_insula_ant                 NaN             NaN
# S_circular_insula_inf              43.500          29.688
# S_circular_insula_sup              31.641          29.688
# S_collat_transv_ant                25.781          35.547
# S_front_inf                        58.480          60.938
# S_front_middle                     52.637          46.000
# S_front_sup                        90.000          69.727
# S_intrapariet_and_P_trans          68.875          48.000
# S_oc-temp_lat                      35.250          32.250
# S_oc-temp_med_and_Lingual          21.938          31.000
# S_oc_middle_and_Lunatus           115.000          23.500
# S_occipital_ant                    12.555          22.500
# S_orbital-H_Shaped                 32.797          39.453
# S_orbital_lateral                     NaN          52.000
# S_orbital_med-olfact               72.562          48.000
# S_pericallosal                     51.000          49.000
# S_postcentral                      47.754          33.000
# S_precentral-inf-part              33.594             NaN
# S_suborbital                       43.848          39.453
# S_temporal_inf                     24.000          39.453
# S_temporal_sup                     35.000          28.711
#
# [50 rows x 50 columns]
