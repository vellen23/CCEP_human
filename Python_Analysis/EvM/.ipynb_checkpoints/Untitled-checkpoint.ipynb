# %%
import sys
from threading import *
import wx
import sys

sys.path.append('T:\EL_experiment\Codes\Connectogram')

import os
import pandas as pd
import tkinter as tk
from tkinter import filedialog

import math
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import get_cmap
from matplotlib.lines import Line2D
from matplotlib.path import Path
from more_itertools import unique_everseen
from matplotlib.colors import to_hex
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection
import itertools
import seaborn as sns

import read_data as rd
import plot_funcs as pf


import numpy as np
import pandas as pd
import read_data as rd

from os import path
import matplotlib.pyplot as plt

from globals import DATA_CON_FILEPATH
from ui_connectogram import Ui_MainWindow as mainWindow
from connectogram import Connectrogram

# %%
# init vars
data_con = None
data_nodes = None
data_edges = None
plot_main = None
ax_con = None


figure = Connectrogram()

# %%
#### Load data
data_con_all = pd.read_csv('T:\EL_experiment\Codes\Connectogram\data_con_sleep.csv')
data_con = data_con_all[~np.isnan(data_con_all.DI)]
data_con = data_con.reset_index(drop=True)
data_con = rd.get_Region_data_con(data_con)
for subj in np.unique(data_con.Subj):
    data_con.loc[data_con.Subj == subj, 'Stim'] = data_con.loc[data_con.Subj == subj, 'Stim'] + chan0
    data_con.loc[data_con.Subj == subj, 'Chan'] = data_con.loc[data_con.Subj == subj, 'Chan'] + chan0
    chan0 = np.max(data_con.loc[data_con.Subj == subj, ['Stim', 'Chan']].values) + 1

chan_ID = np.unique(np.concatenate([data_con.Stim, data_con.Chan])).astype('int')
        
data_nodes = rd.get_nodes(chan_ID, data_con)

data_edges = data_con[(data_con.d > 20) (data_con.NREM_LL == 1)]
data_edges = data_edges.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-323bcfa24b24> in <module>
#       3 data_con = data_con_all[~np.isnan(data_con_all.DI)]
#       4 data_con = data_con.reset_index(drop=True)
# ----> 5 data_con = rd.get_Region_data_con(data_con)
#       6 for subj in np.unique(data_con.Subj):
#       7     data_con.loc[data_con.Subj == subj, 'Stim'] = data_con.loc[data_con.Subj == subj, 'Stim'] + chan0
#
# T:\EL_experiment\Codes\Connectogram\read_data.py in get_Region_data_con(data_con)
#      33
#      34 def get_Region_data_con(data_con):
# ---> 35     atlas = pd.read_excel(CIRC_AREAS_FILEPATH, sheet_name='atlas')
#      36     data_con.insert(4,'ChanR', 'U')
#      37     data_con.insert(4,'StimR', 'U')
#
# c:\users\i0328442\appdata\local\programs\python\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# c:\users\i0328442\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# c:\users\i0328442\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1070             else:
#    1071                 ext = inspect_excel_format(
# -> 1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#    1074
#
# c:\users\i0328442\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(path, content, storage_options)
#     948
#     949     with get_handle(
# --> 950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#     952         stream = handle.handle
#
# c:\users\i0328442\appdata\local\programs\python\python37\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: 'circ_areas.xlsx'

# %% [markdown]
# data_nodes.groupby(['Label','Region'])['ID'].count()

# %%
data_edges = data_con[(data_con.d > 80) & (data_con.d < 100) & (data_con.Dir_index == 1)]
data_edges = data_edges.reset_index(drop=True)

# %%
figure.setData(data_con, data_nodes)
figure.clear()
# Out:
# HIPP_ant
# HIPP_post

# %%
data_edges
# Out:
#       Subj   StimA      ChanA           StimR           ChanR   Stim   Chan  \
# 0    EL010     ITS     RostrS  Laterotemporal   Orbitofrontal    8.0   19.0
# 1    EL010  IFGtri        ITS    Dorsofrontal  Laterotemporal   28.0    9.0
# 2    EL011   Tpole        SFS   Mesiotemporal    Dorsofrontal   64.0  150.0
# 3    EL011   Tpole        SFS   Mesiotemporal    Dorsofrontal   67.0  150.0
# 4    EL011     STG        SFS  Laterotemporal    Dorsofrontal   69.0  150.0
# ..     ...     ...        ...             ...             ...    ...    ...
# 392  EL020  LatOrS        SPG   Orbitofrontal        Parietal  769.0  758.0
# 393  EL020  LatOrS  LatS_vert   Orbitofrontal          Insula  770.0  682.0
# 394  EL020  LatOrS  LatS_vert   Orbitofrontal          Insula  770.0  683.0
# 395  EL020  LatOrS  LatS_post   Orbitofrontal          Insula  770.0  711.0
# 396  EL020  LatOrS     LatOrS   Orbitofrontal   Orbitofrontal  771.0  727.0
#
#           Sig  H    LL_sig  Dir_index  Dir_B  t_resp      d   t_LL  t_onset  \
# 0    0.147541  0  3.878125        1.0    1.0      -1  81.87  0.000    0.000
# 1    0.393443  0  3.357926        1.0    1.0      -1  80.10  0.028    0.057
# 2    0.131707  0  5.197419        1.0    1.0      -1  84.55  0.026    0.000
# 3    0.111650  0  4.903117        1.0    1.0      -1  86.58  0.000    0.000
# 4    0.155340  0  4.473790        1.0    1.0      -1  88.60  0.088    0.000
# ..        ... ..       ...        ...    ...     ...    ...    ...      ...
# 392  0.112500  0  3.562821        1.0    1.0      -1  97.42  0.168    0.000
# 393  0.148148  1  5.805808        1.0    1.0      -1  85.73  0.152    0.000
# 394  0.123457  1  9.177397        1.0    1.0      -1  88.90  0.164    0.000
# 395  0.111111  1  2.954484        1.0    1.0      -1  89.55  0.000    0.000
# 396  0.168750  1  4.299017        1.0    1.0      -1  80.09  0.000    0.000
#
#      Dist
# 0    long
# 1    long
# 2    long
# 3    long
# 4    long
# ..    ...
# 392  long
# 393  long
# 394  long
# 395  long
# 396  long
#
# [397 rows x 17 columns]

# %%
figsize = (40, 40)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1, 1, 1)
figure.plot_nodes_jpt(ax)

# %%
plot_hem = "r"
r_nodes = 18

# %%
import read_data as rd
import plot_funcs as pf

# %%
data_edges
# Out:
#       Subj   StimA      ChanA           StimR           ChanR   Stim   Chan  \
# 0    EL010     ITS     RostrS  Laterotemporal   Orbitofrontal    8.0   19.0
# 1    EL010  IFGtri        ITS    Dorsofrontal  Laterotemporal   28.0    9.0
# 2    EL011   Tpole        SFS   Mesiotemporal    Dorsofrontal   64.0  150.0
# 3    EL011   Tpole        SFS   Mesiotemporal    Dorsofrontal   67.0  150.0
# 4    EL011     STG        SFS  Laterotemporal    Dorsofrontal   69.0  150.0
# ..     ...     ...        ...             ...             ...    ...    ...
# 392  EL020  LatOrS        SPG   Orbitofrontal        Parietal  769.0  758.0
# 393  EL020  LatOrS  LatS_vert   Orbitofrontal          Insula  770.0  682.0
# 394  EL020  LatOrS  LatS_vert   Orbitofrontal          Insula  770.0  683.0
# 395  EL020  LatOrS  LatS_post   Orbitofrontal          Insula  770.0  711.0
# 396  EL020  LatOrS     LatOrS   Orbitofrontal   Orbitofrontal  771.0  727.0
#
#           Sig  H    LL_sig  Dir_index  Dir_B  t_resp      d   t_LL  t_onset  \
# 0    0.147541  0  3.878125        1.0    1.0      -1  81.87  0.000    0.000
# 1    0.393443  0  3.357926        1.0    1.0      -1  80.10  0.028    0.057
# 2    0.131707  0  5.197419        1.0    1.0      -1  84.55  0.026    0.000
# 3    0.111650  0  4.903117        1.0    1.0      -1  86.58  0.000    0.000
# 4    0.155340  0  4.473790        1.0    1.0      -1  88.60  0.088    0.000
# ..        ... ..       ...        ...    ...     ...    ...    ...      ...
# 392  0.112500  0  3.562821        1.0    1.0      -1  97.42  0.168    0.000
# 393  0.148148  1  5.805808        1.0    1.0      -1  85.73  0.152    0.000
# 394  0.123457  1  9.177397        1.0    1.0      -1  88.90  0.164    0.000
# 395  0.111111  1  2.954484        1.0    1.0      -1  89.55  0.000    0.000
# 396  0.168750  1  4.299017        1.0    1.0      -1  80.09  0.000    0.000
#
#      Dist
# 0    long
# 1    long
# 2    long
# 3    long
# 4    long
# ..    ...
# 392  long
# 393  long
# 394  long
# 395  long
# 396  long
#
# [397 rows x 17 columns]

# %%
xy0 = [5, 2]
xy1 = [-5,2]
verts = [xy0,[0,0],xy1]

# %%
def to_cartesian(r, theta, theta_units="radians"):
    """
    Converts polar r, theta to cartesian x, y.
    """
    assert theta_units in [
        "radians",
        "degrees",
    ], "kwarg theta_units must specified in radians or degrees"

    if theta > np.pi or theta < -np.pi:
        theta = theta % np.pi
    x = r * np.cos(theta)
    y = r * np.sin(theta)

    return x, y

# %%
import matplotlib.patches as mpatches

# %%
t
# Out:
# 3.5923268067600187

# %%
verts
# Out:
# [(-2.6153253801451544, 9.651946599311902),
#  [0, 0],
#  (9.001275283936822, 4.356264829276118)]

# %%
plt.plot(xy0, 'ro')

# %%
xy0
# Out:
# (7.052652968772155, 7.089434822471345)

# %%
import time

# %%
time.time()
# Out:
# 1677572719.729653

# %%
4.886698961257935

# %%
t0 = time.time()
for i in range(1000):
    t = np.random.random()*2*np.pi
    xy0 = to_cartesian(10, t)
    # plt.plot(xy0[0],xy0[1], 'ro')

    t = np.random.random()*2*np.pi
    xy1 = to_cartesian(10, t)
    # plt.plot(xy1[0],xy1[1], 'ro')

    verts = [xy0,[0,0],xy1]
    X = np.array(verts)
    xx = pf.P(tt, X)
t1 = time.time()
print(t1-t0)
# Out:
# 0.13877511024475098

# %%
import collections
MyTuple=collections.namedtuple("MyTuple", "mynumber, mystring")
m = MyTuple(3, "hello")
m[0]
# Out:
# 3

# %%
TuplePath
# Out:
# __main__.TuplePath

# %%
TuplePath()

# %%
T = TuplePath1 + TuplePath2
#0: 1, xx, c, 3: 2, xx, c

# %%
T.ID
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-173-c664b6cb881f> in <module>
# ----> 1 T.ID
#
# AttributeError: 'tuple' object has no attribute 'ID'

# %%
TuplePath =collections.namedtuple("TuplePath", ['ID', 'Path', 'Color'])
c = [0,0,0]
TuplePath1  = TuplePath(1, xx, c)
TuplePath2 = TuplePath(2, xx, c)

# %%
Book = namedtuple('Book', ['id', 'title', 'authors'])
Book.__doc__ += ': Hardcover book in active collection'
Book.id.__doc__ = '13-digit ISBN'
Book.title.__doc__ = 'Title of first printing'
Book.authors.__doc__ = 'List of authors sorted by last name'

# %%
figsize = (10,10)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1, 1, 1)
lines = []
for i in range(10):
    t = np.random.random()*2*np.pi
    xy0 = to_cartesian(10, t)
    t = np.random.random()*2*np.pi
    xy1 = to_cartesian(10, t)

    verts = [xy0,[0,0],xy1]
    X = np.array(verts)
    xx = pf.P(tt, X)
    line1 = ax.plot(xx[:, 0], xx[:, 1], color=[0, 0, 0], alpha=0.8)
    lines.append(line1[0])

# %%
def setVisibility(lines, visibility: bool):
    for lines in lines:
        lines.set_visible(visibility)

# %%
figsize = (10,10)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1, 1, 1)
ring = mpatches.Wedge((0, 0), 10, 0, 180,width=1)
ax.add_patch(ring)
for i in range(10):
    t = np.random.random()*2*np.pi
    xy0 = to_cartesian(10, t)
    plt.plot(xy0[0],xy0[1], 'ro')

    t = np.random.random()*2*np.pi
    xy1 = to_cartesian(10, t)
    plt.plot(xy1[0],xy1[1], 'ro')

    verts = [xy0,[0,0],xy1]
    X = np.array(verts)
    xx = pf.P(tt, X)
    # plt.plot(xx[:, 0], xx[:, 1], color=[0, 0, 0], alpha=0.8)
    line1 = ax.plot(xx[:, 0], xx[:, 1], color=[0, 0, 0], alpha=0.8)
    lines.append(line1[0])
plt.xlim([-12,12])
plt.ylim([0,12])
# Out:
# (0, 12)

# %%
setVisibility(lines, 0)
plt.show()

# %%
def plot_con(data_edges, ax):
    ####Edges
    for i in range(len(self.data_edges)):  # range(len(data_edges))
        # i = np.random.randint(len(data_edges))
        c0 = self.data_edges.Stim.values[i]
        c1 = self.data_edges.Chan.values[i]
        if (len(self.data_nodes[self.data_nodes.ID == c1]) > 0) & (
                len(self.data_nodes[self.data_nodes.ID == c0]) > 0):
            r1 = self.data_nodes.loc[self.data_nodes.ID == c0, 'Region'].values[0]
            xy0 = self.data_nodes.loc[self.data_nodes.ID == c0, ['x', 'y']].values[0]
            xy1 = self.data_nodes.loc[self.data_nodes.ID == c1, ['x', 'y']].values[0]
            verts = [xy0,
                     ((-1) ** (np.array(self.plot_hem == 'l') * 1) * self.r_nodes / 3, 0),
                     xy1,
                     ]

            X = np.array(verts)
            n = 100
            tt = np.linspace(0, 1, n)
            xx = pf.P(tt, X)

            ax.plot(xx[:int(n / 2), 0], xx[:int(n / 2), 1], color=[0, 0, 0], alpha=0.3)
            if len(self.circ_areas.loc[self.circ_areas.Area == r1, 'color'].values) > 0:
                col = self.circ_areas.loc[self.circ_areas.Area == r1, 'color'].values[0]
            else:
                col = 'k'
            ax.plot(xx[int(n / 2) - 1:, 0], xx[int(n / 2) - 1:, 1], color=col, alpha=0.3)
    if self.plot_hem == 'l':
        ax.set_xlim([-30, 10])
    else:
        ax.set_xlim([-10, 30])
    ax.set_ylim([-30, 30])
    despine(ax)

    return ax
