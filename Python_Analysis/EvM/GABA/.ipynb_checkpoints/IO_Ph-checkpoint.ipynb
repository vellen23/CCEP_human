# %%
import Human_IO_plots
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# ## Loading data for selected patient

# %%
path_general = 'X:\\4 e-Lab\EvM\Projects\EL_experiment\Analysis\Patients\\'
# path_patient_analysis = 'X:\\4 e-Lab\EvM\Projects\EL_experiment\Analysis\Patients\\'+subj
subj ='EL003'
EEG_resp, con_trial, labels_all = Human_IO_plots.load_data(path_general, subj)

# %% [markdown]
# general parameters used in these figures

# %%
cond_labels = ['BM', 'BL', 'Fuma', 'Benzo']
cond_colors = ['594157', '#594157', "#F1BF98","#8FB996"]
Fs = 500
t0 = 1
dur            = np.zeros((1,2), dtype=np.int32)
t0 = 1
dur[0,0] =  -t0
dur[0,1] =  3
x_ax           = np.arange(dur[0,0],dur[0,1],(1/Fs))

# %% [markdown]
# ### Plot CCEP and LL

# %% [markdown]
# Plot mean CCEP and corresponding LL transform for a given connection and condition

# %%
# select Stim channel (sc), response channel (rc) and Condition (cond)
sc = 9
rc = 0
cond = 1 # 1: BL, 3: BZD

fig, axes = Human_IO_plots.plot_CCEP_LL(sc, rc, con_trial, EEG_resp, cond= cond, w=0.25)
plt.suptitle(subj+' -- '+labels_all[sc]+', Resp: '+labels_all[rc]+', '+cond_labels[cond])
plt.tight_layout()
plt.show()

# %%
cond = 3 # 1: BL, 3: BZD

fig, axes = Human_IO_plots.plot_CCEP_LL(sc, rc, con_trial, EEG_resp, cond= cond, w=0.25)
plt.suptitle(subj+' -- '+labels_all[sc]+', Resp: '+labels_all[rc]+', '+cond_labels[cond])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot CCEP and AUC for both conditions

# %% [markdown]
# Select for what Intensities the mean CCEP should be plotte (Int_all). Conditons should be  [1, 3] to plot BL and BZD. The IO curve across all intensities is plottted in the last subplot

# %%
# select intensities to plot (array)
int_sel = [2, 3, 10] # [2]

fig = Human_IO_plots.plot_CCEP_IO(sc, rc, con_trial, EEG_resp, Int_all =int_sel, conditions = [1, 3], ylim = 600)
plt.suptitle(subj+' -- '+labels_all[sc]+', Resp: '+labels_all[rc])
plt.tight_layout()
plt.show()
